# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import time

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs 
coords = list(lat_lngs)

# %%
cities = []
for coordinate in coords:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 618

# %%
import requests 
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c3c085fb6604e494559d8993a3b68c4d

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
r = 0
s = 0
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1   
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port shepstone
# No precipitation
# Processing Record 2 of Set 1 | bluff
# No precipitation
# Processing Record 3 of Set 1 | ushuaia
# No precipitation
# Processing Record 4 of Set 1 | osoyoos
# No precipitation
# Processing Record 5 of Set 1 | eyrarbakki
# No precipitation
# Processing Record 6 of Set 1 | arraial do cabo
# No precipitation
# Processing Record 7 of Set 1 | rikitea
# No precipitation
# Processing Record 8 of Set 1 | almendralejo
# No precipitation
# Processing Record 9 of Set 1 | mataura
# No precipitation
# Processing Record 10 of Set 1 | airai
# No precipitation
# Processing Record 11 of Set 1 | paita
# No precipitation
# Processing Record 12 of Set 1 | aklavik
# No precipitation
# Processing Record 13 of Set 1 | hobart
# No precipitation
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# No precipitation
# Processing Record 15 of Set 1 | albany
# No precipitation
# Processing Record 16 of Set 1 | jamestown
# No precipitation
# Processing Record 17 of Set 1 | vardo
# No precipitation
# Processing Record 18 of Set 1 | olafsvik
# City not found. Skipping...
# No precipitation
# Processing Record 19 of Set 1 | buala
# No precipitation
# Processing Record 20 of Set 1 | cape town
# No precipitation
# Processing Record 21 of Set 1 | west wendover
# No precipitation
# Processing Record 22 of Set 1 | fort nelson
# No precipitation
# Processing Record 23 of Set 1 | westport
# No precipitation
# Processing Record 24 of Set 1 | lagoa
# No precipitation
# Processing Record 25 of Set 1 | lanxi
# No precipitation
# Processing Record 26 of Set 1 | carnarvon
# No precipitation
# Processing Record 27 of Set 1 | busselton
# No precipitation
# Processing Record 28 of Set 1 | tasiilaq
# No precipitation
# Processing Record 29 of Set 1 | tabou
# No precipitation
# Processing Record 30 of Set 1 | hilo
# No precipitation
# Processing Record 31 of Set 1 | punta arenas
# No precipitation
# Processing Record 32 of Set 1 | tawkar
# City not found. Skipping...
# No precipitation
# Processing Record 33 of Set 1 | fortuna
# No precipitation
# Processing Record 34 of Set 1 | marau
# No precipitation
# Processing Record 35 of Set 1 | corinto
# No precipitation
# Processing Record 36 of Set 1 | pevek
# No precipitation
# Processing Record 37 of Set 1 | mar del plata
# No precipitation
# Processing Record 38 of Set 1 | cockburn town
# No precipitation
# Processing Record 39 of Set 1 | salinopolis
# No precipitation
# Processing Record 40 of Set 1 | medicine hat
# No precipitation
# Processing Record 41 of Set 1 | vaini
# No precipitation
# Processing Record 42 of Set 1 | geraldton
# No precipitation
# Processing Record 43 of Set 1 | ahipara
# No precipitation
# Processing Record 44 of Set 1 | lebu
# No precipitation
# Processing Record 45 of Set 1 | chokurdakh
# No precipitation
# Processing Record 46 of Set 1 | torbay
# No precipitation
# Processing Record 47 of Set 1 | wasilla
# No precipitation
# Processing Record 48 of Set 1 | evensk
# No precipitation
# Processing Record 49 of Set 1 | oranjemund
# No precipitation
# Processing Record 50 of Set 1 | alofi
# No precipitation
# Processing Record 1 of Set 2 | praia da vitoria
# No precipitation
# Processing Record 2 of Set 2 | barrow
# No precipitation
# Processing Record 3 of Set 2 | kaitangata
# No precipitation
# Processing Record 4 of Set 2 | isangel
# No precipitation
# Processing Record 5 of Set 2 | coxim
# No precipitation
# Processing Record 6 of Set 2 | cabo san lucas
# No precipitation
# Processing Record 7 of Set 2 | bredasdorp
# No precipitation
# Processing Record 8 of Set 2 | kapaa
# No precipitation
# Processing Record 9 of Set 2 | sao felix do xingu
# No precipitation
# Processing Record 10 of Set 2 | chardara
# City not found. Skipping...
# No precipitation
# Processing Record 11 of Set 2 | puerto ayora
# No precipitation
# Processing Record 12 of Set 2 | beyneu
# No precipitation
# Processing Record 13 of Set 2 | atuona
# No precipitation
# Processing Record 14 of Set 2 | vangaindrano
# No precipitation
# Processing Record 15 of Set 2 | nikolskoye
# No precipitation
# Processing Record 16 of Set 2 | atikokan
# No precipitation
# Processing Record 17 of Set 2 | hermanus
# No precipitation
# Processing Record 18 of Set 2 | rio claro
# No precipitation
# Processing Record 19 of Set 2 | khatanga
# No precipitation
# Processing Record 20 of Set 2 | ribeira grande
# No precipitation
# Processing Record 21 of Set 2 | teknaf
# No precipitation
# Processing Record 22 of Set 2 | san luis
# No precipitation
# Processing Record 23 of Set 2 | nelson bay
# No precipitation
# Processing Record 24 of Set 2 | ati
# No precipitation
# Processing Record 25 of Set 2 | castro
# No precipitation
# Processing Record 26 of Set 2 | grand-santi
# No precipitation
# Processing Record 27 of Set 2 | buariki
# City not found. Skipping...
# No precipitation
# Processing Record 28 of Set 2 | port blair
# No precipitation
# Processing Record 29 of Set 2 | winslow

# %%
len(city_data)
# Out:
# 538

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Shepstone -30.74   30.45     71.51        95          99
# 1              Bluff -23.58  149.07     85.55        45           5
# 2            Ushuaia -54.81  -68.31     51.80        62          40
# 3            Osoyoos  49.03 -119.47     41.00        98          75
# 4         Eyrarbakki  63.86  -21.15     35.60        80          75
# ..               ...    ...     ...       ...       ...         ...
# 533          Neuquen -38.95  -68.06     73.40        25           5
# 534       Zabaykalsk  49.64  117.33      3.24        87         100
# 535           Skagen  58.60   13.44     44.01        93          98
# 536           Beloha -25.17   45.06     72.25        84           0
# 537  Haines Junction  60.75 -137.51     -7.37        83          51
#
#      Wind Speed Country Weather Description                 Date
# 0          3.24      ZA          light rain  2020-01-05 22:41:33
# 1         14.34      AU           clear sky  2020-01-05 22:41:33
# 2         26.40      AR    scattered clouds  2020-01-05 22:37:57
# 3         27.51      CA         shower rain  2020-01-05 22:41:34
# 4          9.17      IS       broken clouds  2020-01-05 22:41:34
# ..          ...     ...                 ...                  ...
# 533       21.92      AR           clear sky  2020-01-05 22:43:43
# 534        5.26      CN     overcast clouds  2020-01-05 22:43:43
# 535       14.99      SE     overcast clouds  2020-01-05 22:43:44
# 536       10.25      MG           clear sky  2020-01-05 22:43:44
# 537        4.43      CA       broken clouds  2020-01-05 22:40:55
#
# [538 rows x 10 columns]
